# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets
train = pd.read_csv('../data/forecast_train.csv', parse_dates=['timestamp'])
test  = pd.read_csv('../data/forecast_test.csv',  parse_dates=['timestamp'])

print('Train shape:', train.shape)
print('Test  shape:', test.shape)
# Out:
# Train shape: (7027, 24)
# Test  shape: (1757, 23)

# %%
# Quick overview
train.head()
# Out:
#             timestamp  feature_0   feature_1  feature_2  feature_3  feature_4  \
# 0 2024-08-01 00:00:00 -61.862703  142.349008  12.747417   3.174739  40.357354
# 1 2024-08-01 01:00:00 -45.888733   83.852442  10.359977  21.212798  29.339619
# 2 2024-08-01 02:00:00 -48.304941   99.982971  12.229381   8.194864   0.791064
# 3 2024-08-01 03:00:00 -55.389187  107.742835  12.427509 -10.460110  49.167427
# 4 2024-08-01 04:00:00 -67.154621  114.802077  12.301098   6.022369  41.170824
#
#    feature_5  feature_6  feature_7   feature_8  ...  feature_13  feature_14  \
# 0  56.600269  28.011959 -37.428053   99.865707  ...  -57.206920  -81.256057
# 1  46.718673  -5.521119  -7.187384  133.386806  ...    9.524266  -48.100021
# 2  43.001056 -11.083204 -19.555910  106.779528  ...  -42.142713  -52.843723
# 3  49.403362  -3.061455  -6.009953   95.792196  ...  -37.291848  -79.344767
# 4  26.046500   3.300123 -11.210541   86.950222  ...   -2.629173  -60.527968
#
# ...

# %%
train.info()
print()
train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7027 entries, 0 to 7026
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        7027 non-null   datetime64[ns]
#  1   feature_0        7027 non-null   float64
#  2   feature_1        7027 non-null   float64
#  3   feature_2        7027 non-null   float64
#  4   feature_3        7027 non-null   float64
#  5   feature_4        7027 non-null   float64
#  6   feature_5        7027 non-null   float64
#  7   feature_6        7027 non-null   float64
#  8   feature_7        7027 non-null   float64
#  9   feature_8        7027 non-null   float64
#  10  feature_9        7027 non-null   float64
#  11  feature_10       7027 non-null   float64
#  12  feature_11       7027 non-null   float64
#  13  feature_12       7027 non-null   float64
#  14  feature_13       7027 non-null   float64
#  15  feature_14       7027 non-null   float64
# ...

# %%
# Plot actual power output over time
plt.figure(figsize=(14, 4))
plt.plot(train['timestamp'], train['actual_mw'], linewidth=0.8)
plt.title('Actual MW over time (train)')
plt.xlabel('Timestamp')
plt.ylabel('MW')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 5))
# plt.plot(train['timestamp'], train['actual_mw'],      label='Actual',          linewidth=0.8)
plt.plot(train['timestamp'], train['forecast_zephyr'], label='Forecast Zephyr', linewidth=0.8, alpha=0.7)
plt.plot(train['timestamp'], train['forecast_boreas'], label='Forecast Boreas', linewidth=0.8, alpha=0.7)
plt.title('Actual vs Predicted MW')
plt.xlabel('Timestamp')
plt.ylabel('MW')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(train['timestamp'], train['actual_mw'],      label='Actual',          linewidth=0.8)
# plt.plot(train['timestamp'], train['forecast_zephyr'], label='Forecast Zephyr', linewidth=0.8, alpha=0.7)
plt.plot(train['timestamp'], train['forecast_boreas'], label='Forecast Boreas', linewidth=0.8, alpha=0.7)
plt.title('Actual vs Predicted Boreas')
plt.xlabel('Timestamp')
plt.ylabel('MW')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(train['timestamp'], train['actual_mw'],      label='Actual',          linewidth=0.8)
plt.plot(train['timestamp'], train['forecast_zephyr'], label='Forecast Zephyr', linewidth=0.8, alpha=0.7)
# plt.plot(train['timestamp'], train['forecast_boreas'], label='Forecast Boreas', linewidth=0.8, alpha=0.7)
plt.title('Actual vs Predicted Zephyr')
plt.xlabel('Timestamp')
plt.ylabel('MW')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def evaluate(name, y_true, y_pred):
    mae  = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    mbe  = np.mean(y_pred - y_true)
    r2   = r2_score(y_true, y_pred)
    print(f"--- {name} ---")
    print(f"  MAE:  {mae:.3f} MW")
    print(f"  RMSE: {rmse:.3f} MW")
    print(f"  MAPE: {mape:.2f} %")
    print(f"  MBE:  {mbe:.3f} MW")
    print(f"  R²:   {r2:.4f}")
    print()

evaluate('Zephyr', train['actual_mw'], train['forecast_zephyr'])
evaluate('Boreas', train['actual_mw'], train['forecast_boreas'])
# Out:
# --- Zephyr ---
#   MAE:  35.234 MW
#   RMSE: 46.761 MW
#   MAPE: 7.45 %
#   MBE:  28.306 MW
#   R²:   0.6098
#
# --- Boreas ---
#   MAE:  24.044 MW
#   RMSE: 33.517 MW
#   MAPE: 5.40 %
#   MBE:  5.604 MW
#   R²:   0.7995
